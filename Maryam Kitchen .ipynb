# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("MaryamKitchen_2022-04-14.csv")
data
# Out:
#             ID                                              TITLE  \
# 0  WkA8CX-wE3Q  Amazing 🍳 Cake Recipe | پین کیک بنانے کا طریقہ...
# 1  SpYCpvL7vEU  Kofta Pulao Recipe | قوفتہ پلاؤ بنا نے کا طریق...
# 2  7_28HJfO3JM  Easy Omelette Pizza Recipe | آملیٹ پیزا بنانے ...
# 3  6bbzDRWt_xg    Vegetable Fried Rice Recipe By Maryam's Kitchen
# 4  ZgFg6x2pdf0  If you have these Ingredients at Home, You can...
# 5  2dJu71-C5zU  Bakery Style Bread Chicken Patties without Ove...
# 6  eQQ8pruS1XM  Cup Measuring Fluffy Doughnut Recipe | Fluffy ...
# 7  pU8Mky5AREc  White Beef Yakhni Pulao | بیف یخنی پلاؤ بنانے ...
# 8  wo5lTUn8dNE  Chicken Cheese Spring Roll Recipe | Crispy Chi...
# 9  z_v8hKEeDnc  Rich & Flavourful Shahi Tukre in Unique Style ...
#
#                                          DESCRIPTION DURATION  STATUS  \
# 0  Again Welcome to My Channel with Delicious & E...        -  public
# 1  Kofta Pulao Recipe | قوفتہ پلاؤ بنا نے کا طریق...        -  public
# ...

# %%
# data.LOC [<row lable>,<column lable>]
data.loc[:,"KEYWORDS"]
#Same WorkVIEWS
 # data["type"]
# Out:
# 0                                                  NaN
# 1    kofta biryani recipe, kofta pulao recipe, mary...
# 2    Egg Pizza Recipe, Maryam's Kitchen, Easy Break...
# 3    #howtocook, fried rice, riz sauté, riso fritto...
# 4    food, food recipes, recipes, homemade, homemad...
# 5                                                  NaN
# 6    how to make, how to cook, how to bake, cup mea...
# 7    food insider, street food, food wars, bakra ei...
# 8    chicken cheese spring roll recipe, spring roll...
# 9                                                  NaN
# Name: KEYWORDS, dtype: object

# %%
# data.LOC [<row lable>,<column lable>]
data.loc[:,"VIEWS"]
#Same Work
 #data["VIEWS"]
# Out:
# 0      39
# 1     178
# 2     178
# 3     293
# 4     144
# 5     472
# 6     416
# 7     602
# 8     797
# 9    1439
# Name: VIEWS, dtype: int64

# %%
 data.loc[:,["TITLE"]].value_counts()
# Out:
# TITLE
# Amazing 🍳 Cake Recipe | پین کیک بنانے کا طریقہ | Maryam's Kitchen                                      1
# Bakery Style Bread Chicken Patties without Oven | Must Try Recipe for Every Home | Maryam's Kitchen    1
# Chicken Cheese Spring Roll Recipe | Crispy Chicken Cheese Rolls | Maryam's Kitchen                     1
# Cup Measuring Fluffy Doughnut Recipe | Fluffy Doughball Recipe | Fluffy Donut | Maryam's Kitchen       1
# Easy Omelette Pizza Recipe | آملیٹ پیزا بنانے کی ترکیب | Maryam's Kitchen                              1
# If you have these Ingredients at Home, You can make Delightful Dessert | Maryam's Kitchen              1
# Kofta Pulao Recipe | قوفتہ پلاؤ بنا نے کا طریقہ | Maryam's Kitchen                                     1
# Rich & Flavourful Shahi Tukre in Unique Style | Double Ka Meetha by Maryam's Kitchen                   1
# Vegetable Fried Rice Recipe By Maryam's Kitchen                                                        1
# ...

# %%
arr = data.loc[1,"KEYWORDS"].split(",")
arr
len(arr)
# Out:
# 22

# %%
data.loc[:,"KEYWORDS"]
# Out:
# 0                                                  NaN
# 1    kofta biryani recipe, kofta pulao recipe, mary...
# 2    Egg Pizza Recipe, Maryam's Kitchen, Easy Break...
# 3    #howtocook, fried rice, riz sauté, riso fritto...
# 4    food, food recipes, recipes, homemade, homemad...
# 5                                                  NaN
# 6    how to make, how to cook, how to bake, cup mea...
# 7    food insider, street food, food wars, bakra ei...
# 8    chicken cheese spring roll recipe, spring roll...
# 9                                                  NaN
# Name: KEYWORDS, dtype: object

# %%
data.iloc[3:8]
# Out:
#             ID                                              TITLE  \
# 3  6bbzDRWt_xg    Vegetable Fried Rice Recipe By Maryam's Kitchen
# 4  ZgFg6x2pdf0  If you have these Ingredients at Home, You can...
# 5  2dJu71-C5zU  Bakery Style Bread Chicken Patties without Ove...
# 6  eQQ8pruS1XM  Cup Measuring Fluffy Doughnut Recipe | Fluffy ...
# 7  pU8Mky5AREc  White Beef Yakhni Pulao | بیف یخنی پلاؤ بنانے ...
#
#                                          DESCRIPTION DURATION  STATUS  \
# 3  Restaurant Style Vegetable Fried Rice Recipe B...        -  public
# 4  If you have these Ingredients at Home, You can...        -  public
# 5  Bakery Style Bread Chicken Patties Recipe with...        -  public
# 6  Cup Measuring Fluffy Doughnut Recipe | Fluffy ...        -  public
# 7  Hy All..! Welcome Again  Here is Another Recip...        -  public
#
#   DATE PUBLISHED                                           KEYWORDS  \
# 3     12/28/2021  #howtocook, fried rice, riz sauté, riso fritto...
# ...

# %%
#data.iloc[[4]]
data.loc[[4]]
# Out:
#             ID                                              TITLE  \
# 4  ZgFg6x2pdf0  If you have these Ingredients at Home, You can...
#
#                                          DESCRIPTION DURATION  STATUS  \
# 4  If you have these Ingredients at Home, You can...        -  public
#
#   DATE PUBLISHED                                           KEYWORDS  \
# 4      12/8/2021  food, food recipes, recipes, homemade, homemad...
#
#    VIDIQ SCORE  VIEWS  YT LIKES  ...  FB COMMENTS  FB SHARES  TWEETS  \
# 4    21.509775    144         7  ...            0          0       0
#
#    REDDIT UPVOTES  REDDIT POSTS  REDDIT COMMENTS  DESC LINK COUNT  \
# 4               0             0                0                0
#
#    DESC WORD COUNT  CREATOR SUGGESTED  ENGAGEMENT RATE
# 4               15                  9                2
#
# [1 rows x 24 columns]

# %%
data.loc[data["VIEWS"]==178]
# Out:
#             ID                                              TITLE  \
# 1  SpYCpvL7vEU  Kofta Pulao Recipe | قوفتہ پلاؤ بنا نے کا طریق...
# 2  7_28HJfO3JM  Easy Omelette Pizza Recipe | آملیٹ پیزا بنانے ...
#
#                                          DESCRIPTION DURATION  STATUS  \
# 1  Kofta Pulao Recipe | قوفتہ پلاؤ بنا نے کا طریق...        -  public
# 2  Easy Omelette Pizza Recipe | آملیٹ پیزا بنانے ...        -  public
#
#   DATE PUBLISHED                                           KEYWORDS  \
# 1       2/5/2022  kofta biryani recipe, kofta pulao recipe, mary...
# 2      1/27/2022  Egg Pizza Recipe, Maryam's Kitchen, Easy Break...
#
#    VIDIQ SCORE  VIEWS  YT LIKES  ...  FB COMMENTS  FB SHARES  TWEETS  \
# 1      22.4272    178        18  ...            0          0       0
# 2      22.4272    178        14  ...            0          0       0
#
#    REDDIT UPVOTES  REDDIT POSTS  REDDIT COMMENTS  DESC LINK COUNT  \
# ...

# %%
data.loc[data["VIEWS"]!=178]
# Out:
#             ID                                              TITLE  \
# 0  WkA8CX-wE3Q  Amazing 🍳 Cake Recipe | پین کیک بنانے کا طریقہ...
# 3  6bbzDRWt_xg    Vegetable Fried Rice Recipe By Maryam's Kitchen
# 4  ZgFg6x2pdf0  If you have these Ingredients at Home, You can...
# 5  2dJu71-C5zU  Bakery Style Bread Chicken Patties without Ove...
# 6  eQQ8pruS1XM  Cup Measuring Fluffy Doughnut Recipe | Fluffy ...
# 7  pU8Mky5AREc  White Beef Yakhni Pulao | بیف یخنی پلاؤ بنانے ...
# 8  wo5lTUn8dNE  Chicken Cheese Spring Roll Recipe | Crispy Chi...
# 9  z_v8hKEeDnc  Rich & Flavourful Shahi Tukre in Unique Style ...
#
#                                          DESCRIPTION DURATION  STATUS  \
# 0  Again Welcome to My Channel with Delicious & E...        -  public
# 3  Restaurant Style Vegetable Fried Rice Recipe B...        -  public
# 4  If you have these Ingredients at Home, You can...        -  public
# 5  Bakery Style Bread Chicken Patties Recipe with...        -  public
# ...

# %%
data.loc[data["STATUS"]=="public"]
# Out:
#             ID                                              TITLE  \
# 0  WkA8CX-wE3Q  Amazing 🍳 Cake Recipe | پین کیک بنانے کا طریقہ...
# 1  SpYCpvL7vEU  Kofta Pulao Recipe | قوفتہ پلاؤ بنا نے کا طریق...
# 2  7_28HJfO3JM  Easy Omelette Pizza Recipe | آملیٹ پیزا بنانے ...
# 3  6bbzDRWt_xg    Vegetable Fried Rice Recipe By Maryam's Kitchen
# 4  ZgFg6x2pdf0  If you have these Ingredients at Home, You can...
# 5  2dJu71-C5zU  Bakery Style Bread Chicken Patties without Ove...
# 6  eQQ8pruS1XM  Cup Measuring Fluffy Doughnut Recipe | Fluffy ...
# 7  pU8Mky5AREc  White Beef Yakhni Pulao | بیف یخنی پلاؤ بنانے ...
# 8  wo5lTUn8dNE  Chicken Cheese Spring Roll Recipe | Crispy Chi...
# 9  z_v8hKEeDnc  Rich & Flavourful Shahi Tukre in Unique Style ...
#
#                                          DESCRIPTION DURATION  STATUS  \
# 0  Again Welcome to My Channel with Delicious & E...        -  public
# 1  Kofta Pulao Recipe | قوفتہ پلاؤ بنا نے کا طریق...        -  public
# ...

# %%
data.loc[data["STATUS"]=="private"]
# Out:
# Empty DataFrame
# Columns: [ID, TITLE, DESCRIPTION, DURATION, STATUS, DATE PUBLISHED, KEYWORDS, VIDIQ SCORE, VIEWS, YT LIKES, YT DISLIKES, YT COMMENTS, FB LIKES, FB REACTIONS, FB COMMENTS, FB SHARES, TWEETS, REDDIT UPVOTES, REDDIT POSTS, REDDIT COMMENTS, DESC LINK COUNT, DESC WORD COUNT, CREATOR SUGGESTED, ENGAGEMENT RATE]
# Index: []
#
# [0 rows x 24 columns]

# %%
# One Hot Encoding
data["KEYWORDS"]=data['KEYWORDS'].replace(np.nan,'none')
data
# Out:
#             ID                                              TITLE  \
# 0  WkA8CX-wE3Q  Amazing 🍳 Cake Recipe | پین کیک بنانے کا طریقہ...
# 1  SpYCpvL7vEU  Kofta Pulao Recipe | قوفتہ پلاؤ بنا نے کا طریق...
# 2  7_28HJfO3JM  Easy Omelette Pizza Recipe | آملیٹ پیزا بنانے ...
# 3  6bbzDRWt_xg    Vegetable Fried Rice Recipe By Maryam's Kitchen
# 4  ZgFg6x2pdf0  If you have these Ingredients at Home, You can...
# 5  2dJu71-C5zU  Bakery Style Bread Chicken Patties without Ove...
# 6  eQQ8pruS1XM  Cup Measuring Fluffy Doughnut Recipe | Fluffy ...
# 7  pU8Mky5AREc  White Beef Yakhni Pulao | بیف یخنی پلاؤ بنانے ...
# 8  wo5lTUn8dNE  Chicken Cheese Spring Roll Recipe | Crispy Chi...
# 9  z_v8hKEeDnc  Rich & Flavourful Shahi Tukre in Unique Style ...
#
#                                          DESCRIPTION DURATION  STATUS  \
# 0  Again Welcome to My Channel with Delicious & E...        -  public
# 1  Kofta Pulao Recipe | قوفتہ پلاؤ بنا نے کا طریق...        -  public
# ...
